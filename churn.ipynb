# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
churn = pd.read_csv('churn.txt')
churn.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.countplot(x="Churn?", data=churn,ax=ax)
plt.savefig("churn.png")

# %%
fig, ax = plt.subplots(figsize=(7,7))

ip_ct=pd.crosstab(churn["Int'l Plan"],churn['Churn?'],normalize='index')
ip_ct.plot.bar(stacked=True, ax=ax)

ip_ct2=pd.crosstab(churn["Int'l Plan"],churn['Churn?'])


display(ip_ct,ip_ct2)
plt.savefig("ıntlplan.png")
# Out:
# Churn?        False.     True.
# Int'l Plan
# no          0.885050  0.114950
# yes         0.575851  0.424149
# Churn?      False.  True.
# Int'l Plan
# no            2664    346
# yes            186    137

# %%
fig, ax = plt.subplots(figsize=(7,7))

vmp_ct=pd.crosstab(churn['VMail Plan'],churn['Churn?'],normalize='index')
vmp_ct.plot.bar(stacked=True, ax=ax)

vmp_ct2=pd.crosstab(churn['VMail Plan'],churn['Churn?'])

display(vmp_ct, vmp_ct2)
plt.savefig("vmailplan.png")
# Out:
# Churn?        False.     True.
# VMail Plan
# no          0.832849  0.167151
# yes         0.913232  0.086768
# Churn?      False.  True.
# VMail Plan
# no            2008    403
# yes            842     80

# %%
fig, ax = plt.subplots(figsize=(20,7))
st_ct=pd.crosstab(churn['State'],churn['Churn?'],normalize='index')
st_ct.plot.bar(stacked=True, ax=ax)
display(st_ct)
plt.savefig("statect.png")
# Out:
# Churn?    False.     True.
# State
# AK      0.942308  0.057692
# AL      0.900000  0.100000
# AR      0.800000  0.200000
# AZ      0.937500  0.062500
# CA      0.735294  0.264706
# CO      0.863636  0.136364
# CT      0.837838  0.162162
# DC      0.907407  0.092593
# DE      0.852459  0.147541
# FL      0.873016  0.126984
# GA      0.851852  0.148148
# HI      0.943396  0.056604
# IA      0.931818  0.068182
# ID      0.876712  0.123288
# IL      0.913793  0.086207
# IN      0.873239  0.126761
# KS      0.814286  0.185714
# KY      0.864407  0.135593
# LA      0.921569  0.078431
# MA      0.830769  0.169231
# MD      0.757143  0.242857
# ME      0.790323  0.209677
# MI      0.780822  0.219178
# MN      0.821429  0.178571
# MO      0.888889  0.111111
# MS      0.784615  0.215385
# MT      0.794118  0.205882
# NC      0.838235  0.161765
# ND      0.903226  0.096774
# NE      0.918033  0.081967
# NH      0.839286  0.160714
# NJ      0.735294  0.264706
# NM      0.903226  0.096774
# ...

# %%
fig, ax = plt.subplots(figsize=(10,7))
csc_ct=pd.crosstab(churn['CustServ Calls'],churn['Churn?'],normalize='index')
csc_ct2=pd.crosstab(churn['CustServ Calls'],churn['Churn?'])
csc_ct.plot.bar(stacked=True, ax=ax)
display(csc_ct,csc_ct2)
plt.savefig("custservcall.png")
# Out:
# Churn?            False.     True.
# CustServ Calls
# 0               0.868006  0.131994
# 1               0.896698  0.103302
# 2               0.885375  0.114625
# 3               0.897436  0.102564
# 4               0.542169  0.457831
# 5               0.393939  0.606061
# 6               0.363636  0.636364
# 7               0.444444  0.555556
# 8               0.500000  0.500000
# 9               0.000000  1.000000
# Churn?          False.  True.
# CustServ Calls
# 0                  605     92
# 1                 1059    122
# 2                  672     87
# 3                  385     44
# 4                   90     76
# 5                   26     40
# 6                    8     14
# 7                    4      5
# 8                    1      1
# 9                    0      2

# %%
fig, ax = plt.subplots(figsize=(20,7))
sns.countplot(x="State", data=churn, ax=ax, color='Tab:Blue', order=churn['State'].value_counts().index )
plt.savefig("states.png")

# %%
# %matplotlib inline
hist= churn.hist(bins=40,figsize=(12,12))
plt.savefig('hist.png')

# %% [markdown]
# korelasyon katsayısına bak

# %%
churn_crrl=churn.corr()
fig,ax= plt.subplots(figsize=(15,15))
sns.heatmap(churn_crrl,annot=True, ax=ax)
plt.savefig('corelinearityheatmap.png')

# %%
churn.drop(["Day Calls", "Day Charge", "Eve Calls", "Eve Charge",
            "Night Calls", "Night Charge","Intl Calls", "Intl Charge", 
            "Area Code", "Phone","VMail Plan"],axis='columns',inplace=True)
churn.head()
# Out:
#   State  Account Length Int'l Plan  VMail Message  Day Mins  Eve Mins  \
# 0    KS             128         no             25     265.1     197.4
# 1    OH             107         no             26     161.6     195.5
# 2    NJ             137         no              0     243.4     121.2
# 3    OH              84        yes              0     299.4      61.9
# 4    OK              75        yes              0     166.7     148.3
#
#    Night Mins  Intl Mins  CustServ Calls  Churn?
# 0       244.7       10.0               1  False.
# 1       254.4       13.7               1  False.
# 2       162.6       12.2               0  False.
# 3       196.9        6.6               2  False.
# 4       186.9       10.1               3  False.

# %%
fig,ax= plt.subplots(figsize=(10,10))
sns.heatmap(churn.corr(),annot=True, linewidths=0.5)
plt.savefig('correlationmatrix.png')

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg= LogisticRegression(solver='lbfgs')

# %%
from sklearn.preprocessing import OneHotEncoder
ohe= OneHotEncoder(sparse= False )

ohe.fit_transform(churn[['State','Churn?',"Int'l Plan"]])
churn.head()
# Out:
#   State  Account Length Int'l Plan  VMail Message  Day Mins  Eve Mins  \
# 0    KS             128         no             25     265.1     197.4
# 1    OH             107         no             26     161.6     195.5
# 2    NJ             137         no              0     243.4     121.2
# 3    OH              84        yes              0     299.4      61.9
# 4    OK              75        yes              0     166.7     148.3
#
#    Night Mins  Intl Mins  CustServ Calls  Churn?
# 0       244.7       10.0               1  False.
# 1       254.4       13.7               1  False.
# 2       162.6       12.2               0  False.
# 3       196.9        6.6               2  False.
# 4       186.9       10.1               3  False.

# %% [markdown]
# 'false' and 'no' equal to 1

# %%
ohe.categories_
# Out:
# [array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#         'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#         'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#         'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#         'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object),
#  array(['False.', 'True.'], dtype=object),
#  array(['no', 'yes'], dtype=object)]

# %%
from sklearn.compose import make_column_transformer

# %%
column_trans = make_column_transformer((OneHotEncoder(),['State',"Int'l Plan",'Churn?']),
                                       remainder='passthrough')

# %%
column_trans.fit_transform(churn)
# Out:
# <3333x62 sparse matrix of type '<class 'numpy.float64'>'
# 	with 30201 stored elements in Compressed Sparse Row format>

# %% [markdown]
# 'State',"Int'l Plan",'Churn?' bu parametrelerin değerlerini tablonun başına koyuyor kalan parametreler sırayla arrayde sıralanıyor

# %% [markdown]
# logreg için pipeline yapılacak

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(column_trans, logreg)

# %%
from sklearn.model_selection import cross_val_score
